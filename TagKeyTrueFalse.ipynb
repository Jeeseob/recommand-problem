# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('data/ProblemDetail.csv')

# %%
df = pd.DataFrame(data)

# %%
df = df.drop(['titleKo'], axis = 1)

# %%
from pathlib import Path

content = Path("taglist.txt").read_text(encoding = 'UTF-8').replace('\n', ' ')
print(type(content))
# Out:
# <class 'str'>

# %%
import re

pattern = r'"key": ".*?"'

taglist = re.findall(pattern, content)

# %%
pattern1 = r'"key":'
pattern2 = r'\''

# %%
taglist = str(taglist)
taglist = re.sub(pattern1, "", taglist)
taglist = re.sub(pattern2, "", taglist)
taglist = re.sub('\[', "", taglist)
taglist = re.sub('\]', "", taglist)
taglist = re.sub('\"', "", taglist)

# %%
print(taglist)
# Out:
#  math,  implementation,  dp,  graphs,  data_structures,  string,  greedy,  bruteforcing,  graph_traversal,  sorting,  geometry,  number_theory,  trees,  segtree,  binary_search,  bfs,  simulation,  arithmetic,  dfs,  ad_hoc,  combinatorics,  prefix_sum,  constructive,  case_work,  bitmask,  dijkstra,  parsing,  backtracking,  hash_set,  disjoint_set,  sweeping,  divide_and_conquer,  tree_set,  priority_queue,  dp_tree,  stack,  two_pointer,  flow,  primality_test,  lazyprop,  dp_bitfield,  game_theory,  arbitrary_precision,  exponentiation_by_squaring,  offline_queries,  parametric_search,  probability,  recursion,  knapsack,  sieve,  bipartite_matching,  precomputation,  mst,  coordinate_compression,  lca,  euclidean,  hashing,  topological_sorting,  floyd_warshall,  scc,  linear_algebra,  convex_hull,  inclusion_and_exclusion,  sparse_table,  fft,  trie,  mcmf,  smaller_to_larger,  calculus,  suffix_array,  geometry_3d,  deque,  kmp,  mitm,  randomization,  cht,  sqrt_decomposition
# ...

# %%
taglist = re.sub(" ", "", taglist)

# %%
taglist = taglist.split(",")

# %%
print(taglist)
# Out:
# ['math', 'implementation', 'dp', 'graphs', 'data_structures', 'string', 'greedy', 'bruteforcing', 'graph_traversal', 'sorting', 'geometry', 'number_theory', 'trees', 'segtree', 'binary_search', 'bfs', 'simulation', 'arithmetic', 'dfs', 'ad_hoc', 'combinatorics', 'prefix_sum', 'constructive', 'case_work', 'bitmask', 'dijkstra', 'parsing', 'backtracking', 'hash_set', 'disjoint_set', 'sweeping', 'divide_and_conquer', 'tree_set', 'priority_queue', 'dp_tree', 'stack', 'two_pointer', 'flow', 'primality_test', 'lazyprop', 'dp_bitfield', 'game_theory', 'arbitrary_precision', 'exponentiation_by_squaring', 'offline_queries', 'parametric_search', 'probability', 'recursion', 'knapsack', 'sieve', 'bipartite_matching', 'precomputation', 'mst', 'coordinate_compression', 'lca', 'euclidean', 'hashing', 'topological_sorting', 'floyd_warshall', 'scc', 'linear_algebra', 'convex_hull', 'inclusion_and_exclusion', 'sparse_table', 'fft', 'trie', 'mcmf', 'smaller_to_larger', 'calculus', 'suffix_array', 'geom
# ...

# %%
df['tag-key'] = df['tag-key'].str.replace(pat = r'[^\w]', repl = r' ', regex = True)
df['tag-key']
# Out:
# 0                  implementation    arithmetic    math
# 1                  implementation    arithmetic    math
# 2             arbitrary_precision    arithmetic    math
# 3                                math    implementation
# 4             arbitrary_precision    arithmetic    math
#                               ...
# 9717                                generating_function
# 9718
# 9719
# 9720      binary_search    bipartite_matching    game_...
# 9721      ad_hoc    bfs    bitmask    combinatorics   ...
# Name: tag-key, Length: 9722, dtype: object

# %%
count1 = 0
for _ in range(0, 191):
    df[taglist[count1]] = np.nan
    count1 = count1 + 1
# Out:
# /var/folders/3v/z83phb8n2dv8c7trsg991wpm0000gn/T/ipykernel_14628/824032969.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[taglist[count1]] = np.nan
# /var/folders/3v/z83phb8n2dv8c7trsg991wpm0000gn/T/ipykernel_14628/824032969.py:3: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[taglist[count1]] = np.nan
# ...

# %%
for i in taglist:
   df[i] = df['tag-key'].str.contains(i, case = False)
# Out:
# /var/folders/3v/z83phb8n2dv8c7trsg991wpm0000gn/T/ipykernel_14628/2087010745.py:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[i] = df['tag-key'].str.contains(i, case = False)

# %%
df
# Out:
#       Unnamed: 0  problemId  level  averageTries  \
# 0              0       1000      1        2.3805
# 1              1       1001      1        1.3998
# 2              2       1271      1        3.0038
# 3              3       1550      4        1.5407
# 4              4       2338      1        1.9607
# ...          ...        ...    ...           ...
# 9717        9717      23132     28        2.5000
# 9718        9718      23467     28        1.0000
# 9719        9719      23667     28        1.0000
# 9720        9720      23679     28        1.6667
# 9721        9721      24902     28        1.0000
#
#                                                 tag-key   math  \
# 0                implementation    arithmetic    math     True
# 1                implementation    arithmetic    math     True
# 2           arbitrary_precision    arithmetic    math     True
# 3                              math    implementation     True
# ...

# %%
df.to_csv("tag_key.csv", mode='w', encoding='utf-8')
